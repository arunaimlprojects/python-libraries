# %% [markdown]
# Here are **20 basic Python interview questions with one-line answers:**
#
# ### **1-5: Basic Concepts**
# 1. **What is Python?**
#    → Python is a high-level, interpreted programming language known for its simplicity and readability.
#
# 2. **What are the key features of Python?**
#    → Python is easy to learn, dynamically typed, interpreted, object-oriented, and supports libraries for AI/ML.
#
# 3. **What is the difference between Python and C/C++?**
#    → Python is dynamically typed and interpreted, while C/C++ are statically typed and compiled.
#
# 4. **Why is indentation important in Python?**
#    → Indentation defines code blocks in Python, replacing the need for curly braces `{}`.
#
# 5. **What does it mean that Python is a dynamically typed language?**
#    → Variable types are determined at runtime, so you don’t need to declare them explicitly.
#
# ### **6-10: Data Types & Variables**
# 6. **What are the different data types in Python?**
#    → Common types include `int`, `float`, `str`, `list`, `tuple`, `set`, `dict`, and `bool`.
#
# 7. **What are mutable and immutable data types? Give examples.**
#    → Mutable (changeable): `list`, `set`, `dict`; Immutable (unchangeable): `int`, `float`, `tuple`, `str`.
#
# 8. **What is the difference between `list`, `tuple`, and `set` in Python?**
#    → `list`: ordered, mutable; `tuple`: ordered, immutable; `set`: unordered, unique elements.
#
# 9. **How do you check the data type of a variable in Python?**
#    → Using `type(variable)`, e.g., `type(5) → <class 'int'>`.
#
# 10. **What is type casting in Python? Give an example.**
#    → Converting one data type to another, e.g., `int("10") → 10`.
#
# ### **11-15: Control Flow & Loops**
# 11. **What are the different types of loops in Python?**
#    → `for` loop (for iteration) and `while` loop (until a condition is met).
#
# 12. **What is the difference between `break`, `continue`, and `pass` statements?**
#    → `break` exits loop, `continue` skips iteration, `pass` is a placeholder.
#
# 13. **What are conditional statements in Python?**
#    → `if`, `elif`, and `else` control flow based on conditions.
#
# 14. **How does a `for` loop work in Python?**
#    → It iterates over a sequence, e.g., `for i in range(5): print(i)`.
#
# 15. **What is the difference between `while` loop and `for` loop?**
#    → `while` loops run based on a condition, `for` loops iterate over sequences.
#
# ### **16-20: Functions & Miscellaneous**
# 16. **How do you define a function in Python?**
#    → Using `def`, e.g., `def greet(): print("Hello")`.
#
# 17. **What is the difference between `return` and `print` in a function?**
#    → `return` gives a value back to the caller, `print` displays output.
#
# 18. **What is recursion in Python?**
#    → A function calling itself to solve problems, e.g., factorial calculation.
#
# 19. **What are *args and **kwargs in Python functions?**
#    → `*args` passes variable arguments as a tuple, `**kwargs` as a dictionary.
#
# 20. **What is the difference between a shallow copy and a deep copy?**
#    → A shallow copy copies references (`copy.copy()`), while a deep copy clones objects (`copy.deepcopy()`).
#
# Let me know if you need explanations! 🚀😊
